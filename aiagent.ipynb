# %% [markdown]
# <a href="https://colab.research.google.com/github/dude1141/sampleAI/blob/main/aiagent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sun May  3 06:03:38 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8             15W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install crewai

# %%
#crewai is aframework that allows us to create agents
# !pip install 'crewai[tools]'

# %%
# from re import search
import os
from crewai import Agent, Task, Crew
from crewai_tools import SerperDevTool
os.environ['GEMINI_API_KEY']= 'AIzaSyDU5YrjJ53M_JJgN2TyLALs8564Xc9eZAU'
os.environ['SERPER_API_KEY'] = 'e4ecaec292370fe11a75e7aa6ae9ca22aae995ea'

search_tool = SerperDevTool()

teacher = Agent(role='Teacher', goal='Explain steps cleary step by step',backstory='Experiecned teacher with example',llm='gemini-2.5-flash',verbose=True)

researcher = Agent(role='Researcher', goal='Find ltest information',backstory='Expert in searching realworld data',
                   tools=[search_tool],llm='gemini-2.5-flash',verbose= True)
simplifier =Agent(role='Simplifier',goal='Make things easy',
                  backstory='Break complex ideas in to simple language',
                  llm='gemini-2.5-flash',verbose= True)
student=Agent(role='Student',goal='Take notes',backstory='write simplenotes',llm='gemini-2.5-flash',verbose=True)

examiner= Agent (role='Examiner',goal='Create questions',backstory='Tests understanding',llm='gemini-2.5-flash',verbose=True)

topic = 'what is difference between agents vs mcp vs agentic ai vs generative ai'

# tasks1 = Task(description=f'search and find 3 import points about this {topic}',
#               expected_output='3 clear points',agent=researcher)

tasks1 = Task(description=f'Explain {topic} in simple steps with examples',
              expected_output='step-by-step explanation',agent=teacher)

tasks2 = Task(description=f'search and find 3 import points about this {topic}',
              expected_output='3 clear points',agent=researcher)

tasks3 = Task(description=f'Simplify the explanation of the {topic}',
              expected_output='very simple explanation',agent=simplifier)

tasks4 = Task(description=f'Write short notes on the {topic} liek a student',
              expected_output='Simple notes',agent=student)

tasks5 = Task(description=f'Create 5 questions about {topic}',
              expected_output='Tests understanding',agent=examiner)

crew = Crew(
    agents=[teacher,researcher,simplifier,student,examiner],
    tasks=[tasks1,tasks2,tasks3,tasks4,tasks5],
    verbose=True)

result = crew.kickoff()
print(result)



#serperdevtool fetch google results in structred format
# Out:
# ╭───────────────────────── 🚀 Crew Execution Started ──────────────────────────╮
# │                                                                              │
# │  Crew Execution Started                                                      │
# │  Name: crew                                                                  │
# │  ID: 3efb36f1-f726-4c55-9456-cfcfe412d776                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 📋 Task Started ───────────────────────────────╮
# │                                                                              │
# │  Task Started                                                                │
# │  Name: Explain what is difference between agents vs mcp vs agentic ai vs     │
# ...

# %%
# from re import search
import os
from crewai import Agent, Task, Crew
from crewai_tools import SerperDevTool
os.environ['GEMINI_API_KEY']= 'AIzaSyDU5YrjJ53M_JJgN2TyLALs8564Xc9eZAU'
os.environ['SERPER_API_KEY'] = 'e4ecaec292370fe11a75e7aa6ae9ca22aae995ea'

search_tool = SerperDevTool()

teacher = Agent(role='Teacher', goal='Explain steps cleary step by step',backstory='Experiecned teacher with example',llm='gemini-2.5-flash',verbose=True)

researcher = Agent(role='Researcher', goal='Find ltest information',backstory='Expert in searching realworld data',
                   tools=[search_tool],llm='gemini-2.5-flash',verbose= True)
simplifier =Agent(role='Simplifier',goal='Make things easy',
                  backstory='Break complex ideas in to simple language',
                  llm='gemini-2.5-flash',verbose= True)
student=Agent(role='Student',goal='Take notes',backstory='write simplenotes',llm='gemini-2.5-flash',verbose=True)

examiner= Agent (role='Examiner',goal='Create questions',backstory='Tests understanding',llm='gemini-2.5-flash',verbose=True)

topic = 'what is difference between agents vs mcp vs agentic ai vs generative ai'

# tasks1 = Task(description=f'search and find 3 import points about this {topic}',
#               expected_output='3 clear points',agent=researcher)

tasks1 = Task(description=f'Explain {topic} in simple steps with examples',
              expected_output='step-by-step explanation',agent=teacher)

tasks2 = Task(description=f'search and find 3 import points about this {topic}',
              expected_output='3 clear points',agent=researcher)

tasks3 = Task(description=f'Simplify the explanation of the {topic}',
              expected_output='very simple explanation',agent=simplifier)

tasks4 = Task(description=f'Write short notes on the {topic} liek a student',
              expected_output='Simple notes',agent=student)

tasks5 = Task(description=f'Create 5 questions about {topic}',
              expected_output='Tests understanding',agent=examiner)

crew = Crew(
    agents=[teacher,researcher,simplifier,student,examiner],
    tasks=[tasks1,tasks2,tasks3,tasks4,tasks5],
    verbose=True)

result = crew.kickoff()
print(result)



#serperdevtool fetch google results in structred format
# Out:
# ╭───────────────────────── 🚀 Crew Execution Started ──────────────────────────╮
# │                                                                              │
# │  Crew Execution Started                                                      │
# │  Name: crew                                                                  │
# │  ID: 1e6f005e-051b-4e99-a1fa-56be7e573925                                    │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── 📋 Task Started ───────────────────────────────╮
# │                                                                              │
# │  Task Started                                                                │
# │  Name: Explain what is difference between agents vs mcp vs agentic ai vs     │
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)
